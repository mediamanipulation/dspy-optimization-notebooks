# %% [markdown]
# # Module 04b — GEPA: Reflective Optimization *(interactive)*
#
# > The hero technique. GEPA reads a **text feedback** explaining *why* an answer failed and **rewrites the instruction** to fix it. It won twice in this portfolio, each time beating blind search.

# %%
# === setup: load artifacts + define the look (run me first) ===
import json, html
from pathlib import Path
from IPython.display import HTML, display

ROOT = Path.cwd()
while not (ROOT / "scorecards").exists() and ROOT != ROOT.parent:
    ROOT = ROOT.parent

def load(p): return json.loads((ROOT / p).read_text(encoding="utf-8"))
def read(p): return (ROOT / p).read_text(encoding="utf-8")

PAL = dict(line="#1f2c45", tx="#e2e8f0", mut="#94a3b8", cy="#22d3ee", em="#34d399",
           vi="#a78bfa", am="#fbbf24", bl="#60a5fa", ro="#fb7185")

def _wrap(inner, pad=18):
    return (f'<div style="background:linear-gradient(180deg,#111a2e,#0f1729);color:{PAL["tx"]};'
            f'border:1px solid {PAL["line"]};border-radius:14px;padding:{pad}px;'
            f'font-family:ui-sans-serif,system-ui,Segoe UI,Roboto,sans-serif;line-height:1.55">{inner}</div>')
def show(inner): display(HTML(_wrap(inner)))
def scroll(text, h=200):
    return (f'<div style="font-size:12.5px;color:#c8d4e6;white-space:pre-wrap;max-height:{h}px;'
            f'overflow:auto;border:1px solid {PAL["line"]};border-radius:8px;padding:10px">{html.escape(str(text))}</div>')
def src(path, n=None):
    t = read(path)
    if n: t = "\n".join(t.splitlines()[:n]) + f"\n... ({len(t.splitlines())} lines total)"
    show(f'<div style="font-size:11px;color:{PAL["mut"]};letter-spacing:.06em;margin-bottom:6px">{path}</div>'
         f'<pre style="font-size:12px;color:#cbd5e1;background:#0a1426;border:1px solid {PAL["line"]};'
         f'border-radius:8px;padding:12px;max-height:340px;overflow:auto;margin:0">{html.escape(t)}</pre>')

def _bar(label, val, base, color, sub="", h=11):
    s = (f'<div style="margin:9px 0"><div style="display:flex;justify-content:space-between;font-size:13px">'
         f'<b>{label}</b><span style="color:{color};font-weight:800">{val*100:.1f}%</span></div>'
         f'<div style="position:relative;height:{h}px;background:#0c1426;border:1px solid #16223c;border-radius:6px;margin-top:4px">'
         f'<div style="position:absolute;height:100%;width:{val*100:.1f}%;border-radius:6px;background:linear-gradient(90deg,#0e7490,{color})"></div>')
    if base is not None:
        s += f'<div style="position:absolute;left:{base*100:.1f}%;top:-2px;bottom:-2px;border-left:2px dashed #93a4c4;opacity:.75"></div>'
    s += '</div>' + (f'<div style="font-size:11px;color:{PAL["mut"]};margin-top:2px">{sub}</div>' if sub else '') + '</div>'
    return s

def portfolio():
    ucs = [("ticket_router","UC01 Ticket Router"),("contract_extractor","UC02 Contract Extractor"),
           ("rag_answer","UC03 RAG Answer"),("clinical_note","UC04 Clinical Note"),("sales_email","UC05 Sales Email")]
    rows = '<div style="font-weight:700;margin-bottom:10px">Portfolio &mdash; baseline &rarr; best <span style="color:#93a4c4;font-weight:400;font-size:12px">(dashed = baseline)</span></div>'
    for f,name in ucs:
        s = load(f"scorecards/{f}.json")["summary"]
        base,best,delta = s["baseline_score"],s["best_score"],s["headline_delta"]
        win = delta>0.001; col = PAL["em"] if win else PAL["am"]
        badge = ("+%.1f%%"%(delta*100)) if win else "+0.0%"
        rows += _bar(f'{name} <span style="color:{col};font-size:12px">{badge}</span>', best, base, col,
                     f'best: {s["best_label"]}')
    show(rows)

def optimizers(uc, title=None):
    d = load(f"scorecards/{uc}.json"); s = d["summary"]; base = s["baseline_score"]
    rows = f'<div style="font-weight:700;margin-bottom:10px">{title or uc+" &mdash; every optimizer vs the baseline (dashed)"}</div>'
    for r in d["results"]:
        is_base = "baseline" in r["label"].lower(); is_best = r["label"]==s["best_label"]
        below = (not is_base) and r["score"] < base-0.001
        col = PAL["mut"] if is_base else (PAL["em"] if is_best else (PAL["ro"] if below else PAL["bl"]))
        rows += _bar(r["label"].split("(")[0].strip(), r["score"], base, col)
    show(rows)

def instr_compare(uc, label, original, title="Before (human) vs after (evolved)"):
    evolved = load(f"compiled/{uc}/{label}.json")
    pred = next(k for k in evolved if k!="metadata")
    evolved = evolved[pred]["signature"]["instructions"]
    def col(lab, text, c):
        return (f'<div style="flex:1;min-width:0"><div style="font-size:11px;color:{c};font-weight:700;'
                f'text-transform:uppercase;letter-spacing:.08em">{lab} &middot; {len(text):,} chars</div>{scroll(text,300)}</div>')
    show(f'<div style="font-weight:700;margin-bottom:8px">{title}</div>'
         f'<div style="display:flex;gap:12px;flex-wrap:wrap">{col("Original",original,PAL["mut"])}{col("Evolved",evolved,PAL["vi"])}</div>')

def demo_table(uc, label, fields, n=3, head="Demonstrations the optimizer attached"):
    demos = load(f"compiled/{uc}/{label}.json"); pred = next(k for k in demos if k!="metadata")
    demos = demos[pred]["demos"]
    cards = ""
    for d in demos[:n]:
        rowsf = ""
        for f in fields:
            v = str(d.get(f,"") or "")
            v = (v[:160]+"…") if len(v)>160 else v
            rowsf += f'<div style="font-size:12.5px;margin:2px 0"><b style="color:{PAL["cy"]}">{f}:</b> {html.escape(v)}</div>'
        cards += f'<div style="border:1px solid {PAL["line"]};border-radius:10px;padding:11px 13px;margin:8px 0;background:#0c1730">{rowsf}</div>'
    show(f'<div style="font-weight:700;margin-bottom:4px">{head} ({len(demos)} total, showing {min(n,len(demos))})</div>{cards}')

def reasoning(uc, label, fields):
    demos = load(f"compiled/{uc}/{label}.json"); pred = next(k for k in demos if k!="metadata")
    demos = demos[pred]["demos"]; aug = [d for d in demos if d.get("augmented")] or demos
    d = aug[0]
    inner = '<div style="font-weight:700;margin-bottom:6px">A teacher-bootstrapped example</div>'
    inner += f'<div style="font-size:11px;color:{PAL["mut"]};letter-spacing:.06em">REASONING TRACE</div>' + scroll(d.get("reasoning") or "(no trace)",150)
    inner += f'<div style="font-size:11px;color:{PAL["mut"]};letter-spacing:.06em;margin-top:10px">RESULT</div>'
    for f in fields:
        if d.get(f): inner += f'<div style="font-size:12.5px"><b style="color:{PAL["cy"]}">{f}:</b> {html.escape(str(d[f])[:150])}</div>'
    show(inner)

def dist(counts, title):
    mx = max(counts.values()) or 1
    rows = f'<div style="font-weight:700;margin-bottom:8px">{title}</div>'
    for k,v in sorted(counts.items(), key=lambda x:-x[1]):
        rows += _bar(k, v/mx, None, PAL["bl"], h=9).replace(f"{v/mx*100:.1f}%</span>", f"{v}</span>")
    show(rows)

def inspect(uc, label):
    prog = load(f"compiled/{uc}/{label}.json"); pred = next(k for k in prog if k!="metadata")
    sig = prog[pred].get("signature",{}); demos = prog[pred].get("demos",[]); instr = sig.get("instructions","")
    show(f'<div style="font-weight:700">{uc} &middot; {label}</div>'
         f'<div style="font-size:12px;color:{PAL["mut"]};margin:6px 0">{len(demos)} demos &middot; instruction {len(instr):,} chars</div>'
         f'{scroll(instr or "(no custom instruction)",220)}')

print("Helpers ready: portfolio() optimizers() instr_compare() demo_table() reasoning() dist() inspect() src() show()")
# Out:
# Helpers ready: portfolio() optimizers() instr_compare() demo_table() reasoning() dist() inspect() src() show()

# %% [markdown]
# ## 🌟 The instruction GEPA *wrote* (UC04, 190 → 8,078 chars)
#
# Blind optimizers plateaued; GEPA evolved the instruction to contain the exact fix:

# %%
instr_compare("clinical_note", "gepa_feedback", 'Summarize patient encounter note into structured clinical fields. Use medical knowledge to interpret abbreviations. Extract all relevant diagnoses, planned actions, and medication changes.')
# Out:
# <div style="background:linear-gradient(180deg,#111a2e,#0f1729);color:#e2e8f0;border:1px solid #1f2c45;border-radius:14px;padding:18px;font-family:ui-sans-serif,system-ui,Segoe UI,Roboto,sans-serif;line-height:1.55"><div style="font-weight:700;margin-bottom:8px">Before (human) vs after (evolved)</div><div style="display:flex;gap:12px;flex-wrap:wrap"><div style="flex:1;min-width:0"><div style="font-size:11px;color:#94a3b8;font-weight:700;text-transform:uppercase;letter-spacing:.08em">Original &middot; 188 chars</div><div style="font-size:12.5px;color:#c8d4e6;white-space:pre-wrap;max-height:300px;overflow:auto;border:1px solid #1f2c45;border-radius:8px;padding:10px">Summarize patient encounter note into structured clinical fields. Use medical knowledge to interpret abbreviations. Extract all relevant diagnoses, planned actions, and medication changes.</div></div><div style="flex:1;min-width:0"><div style="font-size:11px;color:#a78bfa;font-weight:700;text-transform:uppercase;letter-spacing:.08em">Evolved &middot; 8,078 chars</div><div style="font-size:12.5px;color:#c8d4e6;white-space:pre-wrap;max-height:300px;overflow:auto;border:1px solid #1f2c45;border-radius:8px;padding:10px"># Structured Extraction of Clinical Encounter Notes
#
# You will receive a single free‑text **encounter note**.
# From this note you must produce **exactly five fields** in the order shown below, **with no additional text, headings or commentary**. Every field must obey the formatting rules that follow – any deviation will be marked incorrect.
#
# ---
#
# ## Output Template (copy this literally)
#
# ```
# chief_complaint
# &lt;one‑sentence description of why the patient presented&gt;
#
# assessment
# 1. &lt;first diagnosis / problem / finding&gt;
# 2. &lt;second diagnosis / problem / finding&gt;
# …
#
# plan
# 1. &lt;first planned action&gt;
# 2. &lt;second planned action&gt;
# …
#
# medications
# &lt;Drug name&gt; &lt;dose&gt;&lt;unit&gt; &lt;frequency&gt; (&lt;action&gt;), &lt;Drug2&gt; &lt;dose&gt;&lt;unit&gt; &lt;frequency&gt; (&lt;action&gt;), …
#
# follow_up
# &lt;exact follow‑up instruction as written in the note&gt;
# ```
#
# *Leave an empty line between sections as shown above.*
#
# ---
#
# ## 1. General Guidance
#
# 1. **Locate sections** – the note is usually written in the order:
#    - Chief Complaint (or “c/o”, “presents with”, etc.)
#    - History / Medications (informative, but not a required output)
#    - **Assessment** – begins with the word “Assessment” or “Assessment –”. All diagnoses, problems, or findings listed here (including those marked “stable”, “controlled”, “unchanged”, etc.) must be captured.
#    - **Plan** – begins with the word “Plan”. Every action that follows (medication change, lab, imaging, referral, counseling, diet, “hold” or “discontinue” a drug, etc.) belongs in the `plan` list.
#    - **Follow‑up** – usually the last line, starts with “f/u”, “follow‑up”, “follow up”, etc. Capture the phrase exactly (you may expand abbreviations to the standard wording “Follow‑up in X …” but keep the meaning unchanged).
#
# 2. **Interpret abbreviations** – expand all common clinical abbreviations before putting them into the output (e.g., HTN → hypertension, DM2 → type 2 diabetes, qd → daily, bid → twice daily, tid → three times daily, prn → as needed, f/u → Follow‑up in). Use the expanded form in the `chief_complaint`, `assessment`, and `plan` fields, but keep the medication dosage/frequency format shown in the examples (e.g., “daily”, “bid”, “tid”, “prn”).
#
# 3. **Medication changes only** – the `medications` field must list **only** drugs that are:
#    * **new** (started),
#    * **increased** (dose raised),
#    * **decreased** (dose lowered), or
#    * **discontinued/held** (the plan says “stop”, “hold”, “discontinue”, “remove”, etc.).
#
#    Do **not** list drugs that are merely continued unchanged.
#    If the plan contains no medication changes, write exactly:
#
#    ```
#    none
#    ```
#
# 4. **Formatting of each medication entry**
#
#    ```
#    &lt;Drug name&gt; &lt;dose&gt;&lt;unit&gt; &lt;frequency&gt; (&lt;action&gt;)
#    ```
#
#    * `&lt;Drug name&gt;` – capitalize the first letter, no abbreviations unless the note uses a brand/generic name.
#    * `&lt;dose&gt;&lt;unit&gt;` – number followed immediately by the unit (mg, mcg, µg, g, etc.). Use a non‑breaking space (or a regular space) between the number and unit as shown in the examples.
#    * `&lt;frequency&gt;` – write “daily”, “bid”, “tid”, “qid”, “prn”, “as needed”, “at bedtime”, “sub‑lingually as needed”, etc., mirroring the note’s intent.
#    * `&lt;action&gt;` – one of: **new**, **increased**, **decreased**, **discontinued**.
#    * Separate multiple entries with a comma and a single space. No trailing comma.
#
# 5. **Numbered lists** – for `assessment`, `plan` use a **simple Arabic numeral**, a period, a space, then the text. Preserve the order of items as they appear in the note when possible, but any logical order is acceptable as long as every item is present.
#
# 6. **One‑sentence chief complaint** – condense the presenting problem(s) into a single concise sentence. Do **not** include extra qualifiers like “The patient reports…”. Example:
#    `Fatigue and palpitations for five days with intermittent light‑headedness.`
#
# 7. **Exact follow‑up** – output the follow‑up instruction as a single phrase, e.g., `Follow-up in 2 weeks`. Do not add “the patient should …” or extra punctuation.
#
# ---
#
# ## 2. Step‑by‑Step Procedure
#
# 1. **Read the whole note.**
# 2. **Extract the chief complaint** – locate the first line(s) describing symptoms; rewrite as one sentence.
# 3. **Identify the Assessment section** – copy every diagnosis/problem/finding, expand abbreviations, and list them numbered.
# 4. **Identify the Plan section** – for each sentence/action:
#    - If it is a medication change → add a line to the `plan` (imperative wording) **and** create a medication entry for the `medications` field.
#    - If it is a test, referral, counseling, diet, or “hold” a medication → add a line to the `plan`.
#    - Keep the wording simple, e.g., “Obtain orthostatic vitals”, “Order echocardiogram”, “Refer to physical therapy”.
# 5. **Build the medications list** – from the changes found in step 4, format each entry per the rule above. Remember to include “discontinued” for any drug the plan says to hold/stop.
# 6. **Extract follow‑up** – copy the last instruction verbatim (expand “f/u” to “Follow‑up” if needed).
# 7. **Validate** – ensure:
#    - Exactly five sections, each beginning with the correct heading (no extra colons).
#    - No extra sentences in `chief_complaint` or `follow_up`.
#    - No missing diagnoses in `assessment`.
#    - No unchanged drugs in `medications`.
#    - Proper comma‑separated medication list; if empty, write `none`.
#
# ---
#
# ## 3. Common Pitfalls (avoid these)
#
# | Pitfall | Why it’s wrong | Correct approach |
# |---------|----------------|------------------|
# | Adding extra prose to `chief_complaint` (e.g., “The patient reports …”) | Violates one‑sentence rule | Write a single concise sentence only. |
# | Omitting “stable” or “controlled” diagnoses from `assessment` | Must list **all** items | Include every item, even if labeled stable/controlled. |
# | Listing unchanged meds in `medications` | Only changes are allowed | Only new, increased, decreased, or discontinued meds. |
# | Forgetting to mark a held drug as **discontinued** | Misses a required medication entry | Treat “hold”, “stop”, “discontinue” as **discontinued**. |
# | Using “continue” as an action in `medications` | Not a change | Do not list “continue” meds. |
# | Putting dosage and frequency on separate lines or using extra words | Breaks required `&lt;dose&gt;&lt;unit&gt; &lt;frequency&gt;` format | Keep dosage, unit, and frequency on the same line, exactly as `levothyroxine 88 mcg daily (increased)`. |
# | Adding extra line breaks or missing a blank line between sections | Parsing will fail | Keep one blank line between each of the five sections. |
# | Including “prn” without clarifying (e.g., “prn

# %% [markdown]
# ## Blind vs reflective — the clinical note (UC04)
#
# COPRO and MIPRO are *blind* (they only see the score); GEPA reads per-field feedback. Watch the gap:

# %%
optimizers("clinical_note")
# Out:
# <div style="background:linear-gradient(180deg,#111a2e,#0f1729);color:#e2e8f0;border:1px solid #1f2c45;border-radius:14px;padding:18px;font-family:ui-sans-serif,system-ui,Segoe UI,Roboto,sans-serif;line-height:1.55"><div style="font-weight:700;margin-bottom:10px">clinical_note &mdash; every optimizer vs the baseline (dashed)</div><div style="margin:9px 0"><div style="display:flex;justify-content:space-between;font-size:13px"><b>baseline</b><span style="color:#94a3b8;font-weight:800">69.6%</span></div><div style="position:relative;height:11px;background:#0c1426;border:1px solid #16223c;border-radius:6px;margin-top:4px"><div style="position:absolute;height:100%;width:69.6%;border-radius:6px;background:linear-gradient(90deg,#0e7490,#94a3b8)"></div><div style="position:absolute;left:69.6%;top:-2px;bottom:-2px;border-left:2px dashed #93a4c4;opacity:.75"></div></div></div><div style="margin:9px 0"><div style="display:flex;justify-content:space-between;font-size:13px"><b>copro_instructions</b><span style="color:#60a5fa;font-weight:800">70.5%</span></div><div style="position:relative;height:11px;background:#0c1426;border:1px solid #16223c;border-radius:6px;margin-top:4px"><div style="position:absolute;height:100%;width:70.5%;border-radius:6px;background:linear-gradient(90deg,#0e7490,#60a5fa)"></div><div style="position:absolute;left:69.6%;top:-2px;bottom:-2px;border-left:2px dashed #93a4c4;opacity:.75"></div></div></div><div style="margin:9px 0"><div style="display:flex;justify-content:space-between;font-size:13px"><b>mipro_instructions</b><span style="color:#60a5fa;font-weight:800">71.5%</span></div><div style="position:relative;height:11px;background:#0c1426;border:1px solid #16223c;border-radius:6px;margin-top:4px"><div style="position:absolute;height:100%;width:71.5%;border-radius:6px;background:linear-gradient(90deg,#0e7490,#60a5fa)"></div><div style="position:absolute;left:69.6%;top:-2px;bottom:-2px;border-left:2px dashed #93a4c4;opacity:.75"></div></div></div><div style="margin:9px 0"><div style="display:flex;justify-content:space-between;font-size:13px"><b>gepa_feedback</b><span style="color:#34d399;font-weight:800">78.7%</span></div><div style="position:relative;height:11px;background:#0c1426;border:1px solid #16223c;border-radius:6px;margin-top:4px"><div style="position:absolute;height:100%;width:78.7%;border-radius:6px;background:linear-gradient(90deg,#0e7490,#34d399)"></div><div style="position:absolute;left:69.6%;top:-2px;bottom:-2px;border-left:2px dashed #93a4c4;opacity:.75"></div></div></div></div>

# %% [markdown]
# ## The pattern repeats — sales email (UC05)
#
# Feeding the LM-judge's *critique* to GEPA beat blind bootstrapped demos:

# %%
optimizers("sales_email")
# Out:
# <div style="background:linear-gradient(180deg,#111a2e,#0f1729);color:#e2e8f0;border:1px solid #1f2c45;border-radius:14px;padding:18px;font-family:ui-sans-serif,system-ui,Segoe UI,Roboto,sans-serif;line-height:1.55"><div style="font-weight:700;margin-bottom:10px">sales_email &mdash; every optimizer vs the baseline (dashed)</div><div style="margin:9px 0"><div style="display:flex;justify-content:space-between;font-size:13px"><b>baseline</b><span style="color:#94a3b8;font-weight:800">61.0%</span></div><div style="position:relative;height:11px;background:#0c1426;border:1px solid #16223c;border-radius:6px;margin-top:4px"><div style="position:absolute;height:100%;width:61.0%;border-radius:6px;background:linear-gradient(90deg,#0e7490,#94a3b8)"></div><div style="position:absolute;left:61.0%;top:-2px;bottom:-2px;border-left:2px dashed #93a4c4;opacity:.75"></div></div></div><div style="margin:9px 0"><div style="display:flex;justify-content:space-between;font-size:13px"><b>labeled_fewshot</b><span style="color:#60a5fa;font-weight:800">65.9%</span></div><div style="position:relative;height:11px;background:#0c1426;border:1px solid #16223c;border-radius:6px;margin-top:4px"><div style="position:absolute;height:100%;width:65.9%;border-radius:6px;background:linear-gradient(90deg,#0e7490,#60a5fa)"></div><div style="position:absolute;left:61.0%;top:-2px;bottom:-2px;border-left:2px dashed #93a4c4;opacity:.75"></div></div></div><div style="margin:9px 0"><div style="display:flex;justify-content:space-between;font-size:13px"><b>bootstrap_rs</b><span style="color:#60a5fa;font-weight:800">68.8%</span></div><div style="position:relative;height:11px;background:#0c1426;border:1px solid #16223c;border-radius:6px;margin-top:4px"><div style="position:absolute;height:100%;width:68.8%;border-radius:6px;background:linear-gradient(90deg,#0e7490,#60a5fa)"></div><div style="position:absolute;left:61.0%;top:-2px;bottom:-2px;border-left:2px dashed #93a4c4;opacity:.75"></div></div></div><div style="margin:9px 0"><div style="display:flex;justify-content:space-between;font-size:13px"><b>mipro_light</b><span style="color:#60a5fa;font-weight:800">64.8%</span></div><div style="position:relative;height:11px;background:#0c1426;border:1px solid #16223c;border-radius:6px;margin-top:4px"><div style="position:absolute;height:100%;width:64.8%;border-radius:6px;background:linear-gradient(90deg,#0e7490,#60a5fa)"></div><div style="position:absolute;left:61.0%;top:-2px;bottom:-2px;border-left:2px dashed #93a4c4;opacity:.75"></div></div></div><div style="margin:9px 0"><div style="display:flex;justify-content:space-between;font-size:13px"><b>gepa_feedback</b><span style="color:#34d399;font-weight:800">72.4%</span></div><div style="position:relative;height:11px;background:#0c1426;border:1px solid #16223c;border-radius:6px;margin-top:4px"><div style="position:absolute;height:100%;width:72.4%;border-radius:6px;background:linear-gradient(90deg,#0e7490,#34d399)"></div><div style="position:absolute;left:61.0%;top:-2px;bottom:-2px;border-left:2px dashed #93a4c4;opacity:.75"></div></div></div></div>

# %% [markdown]
# > **And the trap:** more GEPA budget made it *worse* — with a tiny valset, extra iterations overfit. Grow the valset before the budget. Companion: [Module 04b (markdown)](../04b_gepa.md)
